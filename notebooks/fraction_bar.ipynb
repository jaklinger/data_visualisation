# %%
# %matplotlib inline
from plotting_libs import fraction_bar as fb

# %%
fb.fraction_bar(counts=[1,2,3,4],
                labels=("cat","dog","sheep","dinosaur"),
                title="Animals")

# %%
fb.fraction_bar(counts=[1,2,3,4],
                labels=("cat","dog","sheep","dinosaur"),
                horizontal=False,cmap_name="Accent")
